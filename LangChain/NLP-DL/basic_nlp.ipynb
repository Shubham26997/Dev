# %%
# %pip install nltk

# %%
corpus = """
Narendra Damodardas Modi[a] (born 17 September 1950) is an Indian politician who has served as the prime minister of India since 2014. Modi was the chief minister of Gujarat from 2001 to 2014 and is the member of parliament (MP) for Varanasi. He is a member of the Bharatiya Janata Party (BJP) and of the Rashtriya Swayamsevak Sangh (RSS), a right-wing Hindutva paramilitary volunteer organisation. He is the longest-serving prime minister outside the Indian National Congress.
"""

# %%
corpus

# %%
import nltk

# %%
token_sent = nltk.sent_tokenize(corpus)

# %%
import re
for each in token_sent:
    re.sub('[^a-zA-Z]', ' ', each)
    # print(each)
    words = nltk.word_tokenize(each) # return the type of list
    print(words)

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmer.stem("eat")
for each_sent in token_sent:
    # print(each_sent)
    # word_list = [each_word for each_word in each_sent.split()]
    # print(word_list)
    print([stemmer.stem(word=each_word) for each_word in each_sent.split()])
# PorterStemmer.stem()

# %%
from nltk.stem import RegexpStemmer # this works on regex based along with min words len beyond which only stemming will be applied
from nltk.stem import SnowballStemmer # this required a language at the class initialize to stem accordingly

# %%
from nltk.stem import WordNetLemmatizer

lemmate = WordNetLemmatizer()

lemmate.lemmatize("nesting", pos='n')

# %%
nltk.pos_tag([stemmer.stem(word=each_word) for each_word in each_sent.split()])

# %%
from nltk.corpus import stopwords
set(stopwords.words('english'))

# %%
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger_eng')

# %%
# %pip install scikit-learn

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorize = CountVectorizer()

X = vectorize.fit_transform(token_sent)

# %%
vectorize.get_feature_names_out()

# %%
X[0].toarray()
